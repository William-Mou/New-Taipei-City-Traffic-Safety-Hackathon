# %%
#載入資料
import csv
import numpy as np

# 開啟 CSV 檔案
with open('106年樞紐分析表(有交叉路名及其他地點).csv', newline='',encoding="big5") as accident:
    accident = csv.reader(accident)
    accident = [row for row in accident]

# %%
for i in range(len(accident[0])):
    print(i,accident[0][i], end = " ")
print("")

effective_item = [5,7,13,14,43,47]
#effective_item = [23,24,25]
for i in effective_item:
    print(i,accident[0][i])

for i in accident:
    #print(i[7],end = " ")
    try:
        #if "不明原因肇事" in i[13]:
        #    del i[13] 
        #if i[7] == "-1":
        #    del i[7] 
        #else:
            # age 轉換成年齡範圍
            i[7] = str(int(i[7])//10 * 10)
            #print(i[7])

            
    except:
        pass
# Out:
# 0  發生年 1  發生月 2  發生日 3  處理單位(分局別) 4  處理單位(派出所) 5  鄉鎮市 6  道路型態 7  年齡 8  屬性 9  死亡人數 10  受傷人數 11  當事人別 12  當事者區分 13  肇事原因 14  路段 15  巷 16  弄 17  門牌號 18  交叉路名 19  事故類別 20  發生時間 21  事故類型及型態 22  其他地點 23  天候 24  光線 25  道路類別 26  速限 27  事故位置 28  路面狀況-路面鋪裝 29  路面狀況-路面狀態 30  路面狀況-路面缺陷 31  道路障礙-障礙物視距 32  道路障礙-視距 33  號誌-號誌種類 34  號誌-號誌動作 35  車道劃分設施-分道設施-快車道或一般車道間 36  車道劃分設施-分道設施-快慢車道間 37  車道劃分設施-分道設施-路面邊線 38  車道劃分設施-分向設施 39  保護裝備 40  當事者行動狀態 41  駕駛資格情形 42  駕駛執照種類 43  飲酒情形 44  交通事故逃逸 45  受傷程度 46  主要傷處 47  行動電話、電腦或其他相類功能裝置 48  肇事逃逸 49  公路 50  公里 51  公尺 52  方向 53  車道 54  件數
# 5  鄉鎮市
# 7  年齡
# 13  肇事原因
# 14  路段
# 43  飲酒情形
# 47  行動電話、電腦或其他相類功能裝置

# %%
acc = []
for i in range(1,len(accident)):
    township_dict = {}
    #print(accident[i][-10])
    if accident[i][-10] == "24小時內死亡" or accident[i][-10] == "2-30日內死亡":
        #acc.append([])
        for j in range(len(effective_item)):
            township_dict[accident[0][effective_item[j]][1:]] = accident[i][effective_item[j]]
        acc.append(township_dict)
    
import json

township_dead_json = json.dumps(acc,ensure_ascii=False)
print(township_dead_json)
f = open("township_dead.json",'a')
f.write(township_dead_json)
f.close()
# Out:
# [{"鄉鎮市": "五股區", "年齡": "40", "肇事原因": "26違反特定標誌(線)禁制", "路段": "五股區中興路2段", "飲酒情形": "經呼氣檢測0.41~0.55mg/L或血液檢測0.081%~0.11%", "行動電話、電腦或其他相類功能裝置": "不明"}, {"鄉鎮市": "板橋區", "年齡": "30", "肇事原因": "21酒醉(後)駕駛失控", "路段": "板橋區環河西路4段", "飲酒情形": "經呼氣檢測0.56~0.80mg/L或血液檢測0.111%~0.16%", "行動電話、電腦或其他相類功能裝置": "未使用"}, {"鄉鎮市": "三峽區", "年齡": "60", "肇事原因": "53穿越道路未注意左右來車", "路段": "三峽區介壽路", "飲酒情形": "非駕駛人，未檢測", "行動電話、電腦或其他相類功能裝置": "非汽(機)車駕駛人"}, {"鄉鎮市": "板橋區", "年齡": "70", "肇事原因": "52未依標誌、標線、號誌或手勢指揮穿越道路", "路段": "板橋區三民路2段", "飲酒情形": "非駕駛人，未檢測", "行動電話、電腦或其他相類功能裝置": "非汽(機)車駕駛人"}, {"鄉鎮市": "中和區", "年齡": "70", "肇事原因": "67尚未發現肇事因素", "路段": "中和區中正路", "飲酒情形": "非駕駛人，未檢測", "行動電話、電腦或其他相類功能裝置": "非汽(機)車駕駛人"}, {"鄉鎮市": "三峽區", "年齡": "70", "肇事原因": "43不明原因肇事", "路段": "三峽區弘道路", "飲酒情形": "不明", "行動電話、電腦或其他相類功能裝置": "不明"}, {"鄉鎮市": "三峽區", "年齡": "70", "肇事原因": "67尚未發現肇事因素", "路段": "三峽區弘道路", "飲酒情形": "非駕駛人，未檢測", "行動電話、電腦或其他相類功能裝置": "不明"}, {"鄉鎮市": "中和區", "年齡": "50", "肇事原因": "44尚未發現肇事因素", "路段": "中和區環河西路", "飲酒情形": "經檢測無酒精反應", "行動電話、電腦或其他相類功能裝置": "未使用"}, {"鄉鎮市"
# ...

# %%
# !/usr/bin/env python
# -*- coding: utf-8 -*-

def loadData():
    return acc[1:]


def createC1(dataSet):
    """
    构建大小为1的所有候选项集的集合
    :param dataSet:
    :return:
    """
    C1 = []
    for transaction in dataSet:
        for item in transaction:
            if not [item] in C1:
                C1.append([item])
    C1.sort()
    return list(map(frozenset, C1))


def scanD(D, Ck, minSupport):
    """
    Ck中的元素经过最小支持度过滤得到Lk，和每个元素的支持度
    :param D: 数据集
    :param Ck:
    :param minSupport: 最小支持度（过滤）
    :return:
    过程：
    对数据集中的每条交易记录tran
    对每个候选项集can：
        检查一下can是否是tran的子集：
            如果是：则增加can的计数值
            如果不是：把can的值设为1
    对每个候选项集：
        如果其支持度不低于最小值，则保留该项集
    返回所有频繁项集列表
    """
    ssCnt = {}
    for tid in D:
        for can in Ck:
            if can.issubset(tid):
                if can not in ssCnt:
                    ssCnt[can] = 1
                else:
                    ssCnt[can] += 1
    numItems = float(len(D))
    retList = []
    supportData = {}
    for key in ssCnt:
        support = ssCnt[key] / numItems
        if support >= minSupport:
            retList.insert(0, key)
        supportData[key] = support
    return retList, supportData


def aprioriGen(Lk, k):
    """
    合并频繁项集为k个元素
    :param Lk: 频繁项集列表
    :param k: 项集元素个数
    :return:
    """
    retList = []
    lenLk = len(Lk)
    for i in range(lenLk):
        for j in range(i+1, lenLk):
            # 每一个项集同其后面的项集做比较
            # 如果前k-2个元素相同（取不到k-2），则合并为k个元素的项集，添加到retList中
            L1 = list(Lk[i])[:k-2]
            L2 = list(Lk[j])[:k-2]
            L1.sort()
            L2.sort()
            if L1 == L2:
                retList.append(Lk[i] | Lk[j])
    return retList


def Apriori(dataSet, minSupport=0.65):
    """

    :param dataSet: 数据集
    :param minSupport: 最小支持度
    :return:
    过程：
    C1->L1->C2->L2->C3->L3-> ... ->Ck->Lk
    """
    # 单个物品项组成的集合
    C1 = createC1(dataSet)
    # 集合表示的数据集D
    D = list(map(set, dataSet))
    #
    L1, supportData = scanD(D, C1, minSupport)
    L = [L1]
    k = 2
    while len(L[k - 2]) > 0:
        Ck = aprioriGen(L[k - 2], k)
        Lk, supK = scanD(D, Ck, minSupport)
        supportData.update(supK)
        L.append(Lk)
        k += 1
    return L, supportData


def calcConf(freqSet, H, supportData, bigRuleList, minConf=0.65):
    """
    从频繁项集freqSet，计算关联规则(freqSet - H) --> H的置信度
    并过滤置信度低于最小置信度阈值的规则
    :param freqSet: 频繁项集
    :param H: 出现在规则右部
    :param supportData: 支持度字典
    :param bigRuleList: 关联规则列表
    :param minConf: 最小置信度阈值
    :return: 满足最小可信度要求的规则列表
    """
    # 初始化满足最小可信度要求的规则列表
    prunedH = []
    for conseq in H:
        conf = supportData[freqSet] / supportData[freqSet - conseq]
        if conf >= minConf:
            print(freqSet-conseq, "-->", conseq, "conf : ", conf)
            bigRuleList.append((freqSet - conseq, conseq, conf))
            # 与bigRuleList对应的置信度值列表
            prunedH.append(conseq)
    return prunedH


def rulesFromConseq(freqSet, H, supportData, bigRuleList, minConf=0.65):
    """
    由于freqSet中的元素个数大于等于3，计算规则的右部为多个元素的情形
    :param freqSet: 频繁项集
    :param H: 出现在规则右部的元素列表
    :param supportData: 支持度列表
    :param bigRuleList: 关联规则列表
    :param minConf: 最小置信度阈值
    :return:
    """
    m = len(H[0])
    # m + 1，其实示一个递归变量，递归地增加右部元素个数
    if len(freqSet) > (m + 1):
        # 合并元素，任意组合成m+1个元素的项集
        Hmp1 = aprioriGen(H, m + 1)
        # 过滤关联规则(freqSet - Hmp1) --> Hmp1的置信度小于最小置信度阈值的规则
        # 规则右部有m + 1个元素
        Hmp1 = calcConf(freqSet, Hmp1, supportData, bigRuleList, minConf)
        # 递归累加右部元素个数
        if len(Hmp1) > 1:
            rulesFromConseq(freqSet, Hmp1, supportData, bigRuleList, minConf)
    else:
        # 当右部元素个数和频繁项集freqSet的长度一样时，不再划分，返回
        return


def generateRules(L, supportData, minConf=0.65):
    """
    基于给定的频繁项集L和支持度supportData，计算满足最小支持度阈值的规则
    :param L: 频繁项集列表
    :param supportData: 包含那些频繁项集支持数据的字典
    :param minConf: 最小置信度阈值
    :return: 包含可信度的规则列表
    """
    # 初始化规则存放列表
    bigRuleList = []
    # 遍历频繁项集
    for i in range(1, len(L)):
        #
        for freqSet in L[i]:
            # 只包含单个元素集合的列表H1
            H1 = [frozenset([item]) for item in freqSet]
            # 过滤关联规则(freqSet - H1) --> H1的置信度小于最小置信度阈值的规则
            # H1是右部为单个元素的情形
            H1 = calcConf(freqSet, H1, supportData, bigRuleList, minConf)
            if i > 1:
                # 如果频繁项集中元素个数大于等于3，就需要考虑右部为多个元素的情形
                rulesFromConseq(freqSet, H1, supportData, bigRuleList, minConf)
    return bigRuleList


dataSet = loadData()
L, supportData = Apriori(dataSet)
rules = generateRules(L, supportData, minConf=0.7)

f = open('Apriori_Ouput.txt','a')
f.write(str(rules))
print(rules)
# Out:
# frozenset({'市區道路'}) --> frozenset({'無障礙物'}) conf :  0.9553571428571428
# frozenset({'無障礙物'}) --> frozenset({'市區道路'}) conf :  0.8106060606060606
# frozenset({'市區道路'}) --> frozenset({'良好'}) conf :  0.9732142857142856
# frozenset({'良好'}) --> frozenset({'市區道路'}) conf :  0.7898550724637681
# frozenset({'無障礙物'}) --> frozenset({'良好'}) conf :  0.9772727272727272
# frozenset({'良好'}) --> frozenset({'無障礙物'}) conf :  0.9347826086956522
# frozenset({'良好', '市區道路'}) --> frozenset({'無障礙物'}) conf :  0.9633027522935781
# frozenset({'無障礙物', '市區道路'}) --> frozenset({'良好'}) conf :  0.9813084112149533
# frozenset({'良好', '無障礙物'}) --> frozenset({'市區道路'}) conf :  0.813953488372093
# frozenset({'市區道路'}) --> frozenset({'良好', '無障礙物'}) conf :  0.9375
# frozenset({'良好'}) --> frozenset({'無障礙物', '市區道路'}) conf :  0.7608695652173914
# frozenset({'無障礙物'}) --> frozenset({'良好', '市區道路'}) conf :  0.7954545454545454
# ...

# %%
print(acc[:10])
# Out:
# [['14-直路', '40', '車與車-對撞', '市區道路', '路段-一般車道(未劃分快慢車道)', '無障礙物', '良好', '車的狀態-其他'], ['14-直路', '30', '汽(機)車本身-撞交通島', '市區道路', '路段-一般車道(未劃分快慢車道)', '無障礙物', '良好', '車的狀態-向前直行中'], ['03-三岔路', '60', '人與汽(機)車-穿越道路中', '市區道路', '交叉路口-交叉路口內', '無障礙物', '良好', '人的狀態-步行'], ['04-四岔路', '70', '人與汽(機)車-穿越道路中', '市區道路', '交叉路口-交叉路口內', '無障礙物', '良好', '人的狀態-步行'], ['04-四岔路', '70', '人與汽(機)車-穿越道路中', '市區道路', '交叉路口-交叉路口內', '無障礙物', '良好', '人的狀態-步行'], ['11-彎曲路及附近', '70', '194083號燈桿前', '50', '柏油', '不良', '無號誌', '不明'], ['11-彎曲路及附近', '70', '車與車-其他', '市區道路', '路段-一般車道(未劃分快慢車道)', '無障礙物', '不良', '人的狀態-不明'], ['03-三岔路', '50', '車與車-側撞', '市區道路', '交叉路口-交叉路口內', '無障礙物', '良好', '車的狀態-左轉彎'], ['03-三岔路', '70', '人與汽(機)車-穿越道路中', '市區道路', '交叉路口-交叉路口內', '無障礙物', '良好', '人的狀態-步行'], ['10-高架道路', '60', '車與車-對撞', '專用道路', '交流道-直線匝道', '無障礙物', '良好', '人的狀態-其他']]

# %%
num_dict = {}
for i in range(len(accident)):
    if accident[i][5] in num_dict:
        num_dict[accident[i][5] ] += 1
    else:
        num_dict[accident[i][5] ] = 1

# %%
num_dict
# Out:
# {' 鄉鎮市': 1,
#  '五股區': 3293,
#  '板橋區': 10284,
#  '三峽區': 2635,
#  '中和區': 8430,
#  '汐止區': 3100,
#  '八里區': 997,
#  '坪林區': 261,
#  '樹林區': 2168,
#  '三重區': 7617,
#  '石門區': 95,
#  '蘆洲區': 3618,
#  '新莊區': 4311,
#  '土城區': 4363,
#  '萬里區': 215,
#  '金山區': 263,
#  '鶯歌區': 1902,
#  '新店區': 5437,
#  '林口區': 1291,
#  '瑞芳區': 509,
#  '淡水區': 3135,
#  '雙溪區': 84,
#  '石碇區': 323,
#  '泰山區': 2001,
#  '貢寮區': 97,
#  '永和區': 5242,
#  '深坑區': 231,
#  '三芝區': 266,
#  '烏來區': 48,
#  '平溪區': 81}
